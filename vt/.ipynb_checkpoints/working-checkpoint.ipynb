# %%
from scipy.stats import zscore
import pandas as pd

# %%
df = pd.read_csv("./Airbnb_Open_Data.csv")
df.head()
# Out:
# /var/folders/qv/hlnb1jfx68x_r2g75s1fkjlm0000gq/T/ipykernel_25620/2006713868.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
zscore(df["price"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qv/hlnb1jfx68x_r2g75s1fkjlm0000gq/T/ipykernel_25620/2489590776.py in <module>
# ----> 1 zscore(df["price"])
#
# ~/opt/anaconda3/envs/caoep/lib/python3.9/site-packages/scipy/stats/_stats_py.py in zscore(a, axis, ddof, nan_policy)
#    2971            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2972     """
# -> 2973     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#    2974
#    2975
#
# ~/opt/anaconda3/envs/caoep/lib/python3.9/site-packages/scipy/stats/_stats_py.py in zmap(scores, compare, axis, ddof, nan_policy)
#    3135             isconst = np.apply_along_axis(_isconst, axis, a)
#    3136     else:
# -> 3137         mn = a.mean(axis=axis, keepdims=True)
#    3138         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    3139         if axis is None:
#
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %%
df["price"] = df["price"].str.replace("$", "")
df["price"] = df["price"].str.replace(",", "")
df["price"] = df["price"].astype(float)

# %%
zscore(df["price"], nan_policy = "omit")
# Out:
# 0         1.027245
# 1        -1.457152
# 2        -0.015960
# 3        -0.775752
# 4        -1.270219
#             ...
# 102594    0.659410
# 102595    0.638305
# 102596    1.093576
# 102597   -0.239074
# 102598    1.226238
# Name: price, Length: 102599, dtype: float64

# %%
df["minimum nights"] = df["minimum nights"].astype(float)
df["minimum_nights_zscore"] = zscore(df["minimum nights"], nan_policy = "omit")
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... minimum nights number of reviews  \
# ...

# %%
df[df["minimum_nights_zscore"] > 3]
# Out:
#               id                                               NAME  \
# 62       1035579                                                NaN
# 166      1093018  * Spacious GARDEN Park Slope Duplex* 6 people max
# 167      1093570                Convenient cozy cheap apt Manhattan
# 168      1094122                 Parlor Room In Victorian Townhouse
# 169      1094675                     House On Henry (2nd FLR Suite)
# ...          ...                                                ...
# 101796  57223267                   Small Cozy Room in Herald Square
# 101842  57248673                       Beautiful duplex in Gramercy
# 101980  57324890        NYU/E.Village Cafes & Bars*6 month $3500/mo
# 102468  20408053    Clean, Cozy Home in Perfect Park Slope Location
# 102528   6055986                Furnished room in Astoria apartment
#
#             host id host_identity_verified   host name neighbourhood group  \
# ...
