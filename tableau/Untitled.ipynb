# %%
import pandas as pd

# %%
df = pd.read_csv("./WaterQualityWaterQualityStation.csv")
df.head()
# Out:
#   MonitoringStation  EventId  Cruise Program Project Agency  Source  \
# 0       1AACO014.57   674222  NTN024   NTWQM     NTN  VADEQ  USGSVA
# 1       1AACO014.57   674119  NTN024   NTWQM     NTN  VADEQ  USGSVA
# 2       1AACO014.57   672581  NTN024   NTWQM     NTN  VADEQ  USGSVA
# 3       1AACO014.57   672582  NTN024   NTWQM     NTN  VADEQ  USGSVA
# 4       1AACO014.57   672583  NTN024   NTWQM     NTN  VADEQ  USGSVA
#
#        Station SampleDate SampleTime  ...  Unit  Method  Lab  Problem  \
# 0  1AACO014.57    1/10/24   12:00:00  ...  MG/L    F04   NaN      NaN
# 1  1AACO014.57    2/13/24    9:15:00  ...  MG/L    F04   NaN      NaN
# 2  1AACO014.57     3/7/24   10:15:00  ...  MG/L    F04   NaN      NaN
# 3  1AACO014.57    3/13/24   10:15:00  ...  MG/L    F04   NaN      NaN
# 4  1AACO014.57     4/3/24    9:00:00  ...  MG/L    F04   NaN      NaN
#
#   PrecisionPC BiasPC                                            Details  \
# ...

# %%
sorted(df["SampleDate"].unique())
# Out:
# ['1/10/24',
#  '1/11/24',
#  '1/12/24',
#  '1/13/24',
#  '1/16/24',
#  '1/17/24',
#  '1/18/24',
#  '1/2/24',
#  '1/22/24',
#  '1/23/24',
#  '1/24/24',
#  '1/25/24',
#  '1/26/24',
#  '1/28/24',
#  '1/29/24',
#  '1/3/24',
#  '1/30/24',
#  '1/31/24',
#  '1/4/24',
#  '1/7/24',
#  '1/8/24',
#  '1/9/24',
#  '10/15/24',
#  '10/22/24',
#  '10/23/24',
#  '2/1/24',
#  '2/12/24',
#  '2/13/24',
#  '2/14/24',
#  '2/15/24',
#  '2/16/24',
#  '2/19/24',
#  '2/20/24',
#  '2/21/24',
#  '2/22/24',
#  '2/23/24',
#  '2/26/24',
#  '2/27/24',
#  '2/28/24',
#  '2/29/24',
#  '2/5/24',
#  '2/6/24',
#  '2/7/24',
#  '2/8/24',
#  '3/10/24',
#  '3/11/24',
#  '3/12/24',
#  '3/13/24',
#  '3/14/24',
#  '3/15/24',
#  '3/18/24',
#  '3/19/24',
#  '3/20/24',
#  '3/21/24',
#  '3/24/24',
#  '3/25/24',
#  '3/26/24',
#  '3/27/24',
#  '3/28/24',
#  '3/29/24',
#  '3/4/24',
#  '3/5/24',
#  '3/6/24',
#  '3/7/24',
#  '3/8/24',
#  '4/1/24',
#  '4/10/24',
#  '4/11/24',
#  '4/12/24',
#  '4/15/24',
#  '4/16/24',
#  '4/17/24',
# ...
